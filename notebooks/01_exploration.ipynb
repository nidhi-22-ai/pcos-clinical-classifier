# %% [markdown]
# # PCOS Clinical Classifier - Exploration
#
# This notebook is for looking at the data before any modelling. The actual analysis is run from `src/run_analysis.py`.
#
# Read `README.md` and `data/README.md` first. Place the dataset in `data/` before running.

# %%
import sys, os
sys.path.append(os.path.join('..','src'))
import data_prep

df = data_prep.load_data()
data_prep.basic_quality_report(df)
df.head()

# %%
df.describe()

# %% [markdown]
# ## Notes and honest observations
#
# Write here what you actually see. Class balance? Suspicious perfect separators? Features that look like IDs? This is where real understanding goes, not just code.
